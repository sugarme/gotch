# %% [markdown]
# <a href="https://colab.research.google.com/github/sugarme/gotch/blob/master/example/mnist/gotch_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !add-apt-repository ppa:longsleep/golang-backports -y
# !apt update
# !apt install golang-go
# !rm -rf /usr/local/share/jupyter/kernels/gophernotes
# %env GOPATH=/root/go
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/longsleep/golang-backports/ubuntu bionic InRelease [15.4 kB]
# Get:6 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.3 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,023 kB]
# ...

# %%
# Install Libtorch
# !rm -rf libtorch
# !wget https://download.pytorch.org/libtorch/cu101/libtorch-cxx11-abi-shared-with-deps-1.5.1%2Bcu101.zip
# !unzip libtorch-cxx11-abi-shared-with-deps-1.5.1+cu101.zip
# !rm -rf /opt/libtorch
# !mv libtorch /opt
# %env LD_LIBRARY_PATH=/opt/libtorch/lib:/usr/lib64-nvidia:/usr/local/cuda-10.1/lib64
# Out:
# --2020-07-24 03:17:23--  https://download.pytorch.org/libtorch/cu101/libtorch-cxx11-abi-shared-with-deps-1.5.1%2Bcu101.zip
# Resolving download.pytorch.org (download.pytorch.org)... 99.86.91.5, 99.86.91.110, 99.86.91.2, ...
# Connecting to download.pytorch.org (download.pytorch.org)|99.86.91.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 773109672 (737M) [application/zip]
# Saving to: ‘libtorch-cxx11-abi-shared-with-deps-1.5.1+cu101.zip’
#
# libtorch-cxx11-abi- 100%[===================>] 737.29M  39.3MB/s    in 20s
#
# 2020-07-24 03:17:43 (37.5 MB/s) - ‘libtorch-cxx11-abi-shared-with-deps-1.5.1+cu101.zip’ saved [773109672/773109672]
#
# Archive:  libtorch-cxx11-abi-shared-with-deps-1.5.1+cu101.zip
#    creating: libtorch/
#    creating: libtorch/include/
#   inflating: libtorch/include/sleef.h
#    creating: libtorch/include/pybind11/
#   inflating: libtorch/include/pybind11/buffer_info.h
#   inflating: libtorch/include/pybind11/cast.h
# ...

# %%
# %cd /content
# !rm -rf gotch
# !git clone "https://github.com/sugarme/gotch"
# Out:
# /content
# Cloning into 'gotch'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (202/202), done.
# remote: Total 1928 (delta 138), reused 180 (delta 67), pack-reused 1646
# Receiving objects: 100% (1928/1928), 18.48 MiB | 3.02 MiB/s, done.
# Resolving deltas: 100% (1212/1212), done.

# %%
# Prepare data and run MNIST CNN training example
# !mkdir -p /content/gotch/data/mnist
# %cd /content/gotch/data/mnist
# Download MNIST data from http://yann.lecun.com/exdb/mnist/
# !wget http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz

# !gunzip train-images-idx3-ubyte.gz
# !gunzip train-labels-idx1-ubyte.gz
# !gunzip t10k-images-idx3-ubyte.gz
# !gunzip t10k-labels-idx1-ubyte.gz
# Out:
# /content/gotch/data/mnist
# --2020-07-24 03:25:55--  http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 172.67.171.76, 104.28.7.204, 104.28.6.204, ...
# Connecting to yann.lecun.com (yann.lecun.com)|172.67.171.76|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9912422 (9.5M) [application/x-gzip]
# Saving to: ‘train-images-idx3-ubyte.gz’
#
# train-images-idx3-u 100%[===================>]   9.45M  8.39MB/s    in 1.1s
#
# 2020-07-24 03:25:57 (8.39 MB/s) - ‘train-images-idx3-ubyte.gz’ saved [9912422/9912422]
#
# --2020-07-24 03:26:03--  http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 104.28.7.204, 172.67.171.76, 104.28.6.204, ...
# Connecting to yann.lecun.com (yann.lecun.com)|104.28.7.204|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28881 (28K) [application/x-gzip]
# Saving to: ‘train-labels-idx1-ubyte.gz’
#
# ...

# %%
# %cd /content/gotch/example/mnist
# !go run . -model=cnn
# Out:
# /content/gotch/example/mnist
# Epoch: 0	 Loss: 0.25 	 Test accuracy: 93.17%
# Epoch: 1	 Loss: 0.07 	 Test accuracy: 95.91%
# Epoch: 2	 Loss: 0.14 	 Test accuracy: 97.24%
# Epoch: 3	 Loss: 0.09 	 Test accuracy: 97.72%
# Epoch: 4	 Loss: 0.05 	 Test accuracy: 98.24%
# Epoch: 5	 Loss: 0.07 	 Test accuracy: 98.42%
# Epoch: 6	 Loss: 0.06 	 Test accuracy: 98.70%
# Epoch: 7	 Loss: 0.07 	 Test accuracy: 98.58%
# Epoch: 8	 Loss: 0.03 	 Test accuracy: 98.82%
# Epoch: 9	 Loss: 0.05 	 Test accuracy: 98.89%
# Epoch: 10	 Loss: 0.08 	 Test accuracy: 98.97%
# Epoch: 11	 Loss: 0.04 	 Test accuracy: 98.94%
# Epoch: 12	 Loss: 0.05 	 Test accuracy: 98.95%
# Epoch: 13	 Loss: 0.06 	 Test accuracy: 99.08%
# Epoch: 14	 Loss: 0.01 	 Test accuracy: 99.11%
# Epoch: 15	 Loss: 0.04 	 Test accuracy: 99.09%
# Epoch: 16	 Loss: 0.01 	 Test accuracy: 99.11%
# Epoch: 17	 Loss: 0.02 	 Test accuracy: 99.11%
# Epoch: 18	 Loss: 0.04 	 Test accuracy: 99.03%
# Epoch: 19	 Loss: 0.01 	 Test accuracy: 99.03%
# ...
